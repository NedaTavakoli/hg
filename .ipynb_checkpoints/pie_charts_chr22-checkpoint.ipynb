# %%
#1- Variants retained while changing alpha (SNPs), delta = 1%

# %%
N_varinats_greedy = [707279,738563,724871,722216]
N_varinats_LP = [705111,735831,721956,719267]
N_varinats_ILP_Hap = [357279,385531,365598,375126] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [707279,705111,357279]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =150$',fontsize=30)


# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-1-chr22.pdf', bbox_inches="tight")

# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [738563,735831,385531]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =1000$',fontsize=30)
# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-2-chr22.pdf', bbox_inches="tight") 
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [724871,721956,365598]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =5000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)
 
plt.savefig('[SNP]-pie-3-chr22.pdf', bbox_inches="tight")    
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [722216,719267,375126]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'$\delta =1\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =10000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-4-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
# 1- Variants retained while changing alpha (SNPs), delta = 5%

# %%
N_varinats_greedy = [91913,20459,7392,5126]
N_varinats_LP = [91316,20176,7239,5043]
N_varinats_ILP_Hap = [30476,7176,2435,1367] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [91913,91316,30476]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =150$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-5-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [20459,20176,7176]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =1000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-6-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [7392,7239,2435]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =5000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-7-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [5126,5043,1367]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =10000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-8-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
# 1- Variants retained while changing alpha (SNPs), delta = 10%

# %%
N_varinats_greedy = [6906,2538,872,695]
N_varinats_LP = [6746,2426,840,674]
N_varinats_ILP_Hap = [3323,956,296,186] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [6906,6746,3323]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =150$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-9-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [2538,2426,956]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =1000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-10-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [872,840,296]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =5000$',fontsize=30)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-11-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Awarew']
 
# portion covered by each label
slices = [695,674,186]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =10000$',fontsize=25)

# plotting legend
# plt.legend(loc=3)

plt.savefig('[SNP]-pie-12-chr22.pdf', bbox_inches="tight")
# showing the plot
plt.show()
