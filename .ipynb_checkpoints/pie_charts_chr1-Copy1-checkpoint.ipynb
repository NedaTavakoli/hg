# %%
#1- Variants retained while changing alpha (SNPs), delta = 1%

# %%
import math

# %%
N_varinats_greedy = [3956014,4130327,4037224,4022081]
N_varinats_LP = [3946043,4118001,4024542,math.inf]
N_varinats_ILP_Hap = [2355632,2030326,1930345,1783400] # New
alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [3956014,3946043,2355632]

# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =150$',fontsize=30)


# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-1-chr1.pdf', bbox_inches="tight")

# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4130327,4118001,2030326]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =1000$',fontsize=30)
# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-2-chr1.pdf', bbox_inches="tight") 
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4037224,4024542,1930345]


# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =1\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =5000$',fontsize=30)

# plotting legend
plt.legend(loc=3)
 
plt.savefig('[SNP]-pie-3-chr1.pdf', bbox_inches="tight")    
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4022081,math.inf,1783400]

# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'$\delta =1\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =1\%$ $\alpha =10000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-4-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
# 1- Variants retained while changing alpha (SNPs), delta = 10%

# %%
N_varinats_greedy = [346515,40037,8808,5426]
N_varinats_LP = [344842,39679,8734,math.inf]
N_varinats_ILP_Hap = [146312,10034,5342,2065] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [346515,344842,146312]
      
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =150$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-5-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [40037,39679,10034]
 
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =1000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-6-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [8808,8734,5342]
 
    
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =5000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-7-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Awarew']
 
# portion covered by each label
slices = [5426,6000,2065] 

# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =10\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =10\%$ $\alpha =10000$',fontsize=25)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-8-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
# 1- Variants retained while changing alpha (SNPs), delta = 5%

# %%
N_varinats_greedy = [3956014,4130327,4037224,4022081]
N_varinats_LP = [3946043,4118001,4024542,math.inf]
N_varinats_ILP_Hap = [2355632,2030326,1930345,1783400] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [3956014,3946043,2355632]


# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =150$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =150$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-9-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4130327,4118001,2030326]


# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =1000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =1000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-10-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
N_varinats_greedy = [91913,20459,7392,5126]
N_varinats_LP = [91316,20176,7239,5043]
N_varinats_ILP_Hap = [30476,7176,2435,1367] # New

alpha = [150, 1000, 5000, 10000]

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4037224,4024542,1930345]

# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =5000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =5000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-11-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
 
# defining labels
activities = ['Greedy', 'LP', 'ILP Haplotype Aware']
 
# portion covered by each label
slices = [4022081,math.inf, 1783400]
# color for each label
colors = ['navy', 'c', 'slateblue', 'b']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1),
        radius = 1.2, autopct = '%1.1f%%')
#plt.title(r'Variants retained $\delta =5\%$ $\alpha =10000$',fontsize=30)
plt.title(r'$\delta =5\%$ $\alpha =10000$',fontsize=30)

# plotting legend
plt.legend(loc=3)

plt.savefig('[SNP]-pie-12-chr1.pdf', bbox_inches="tight")
# showing the plot
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:2975: RuntimeWarning: invalid value encountered in true_divide
#   x = x / sx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-0f6ec9d5e781> in <module>
#      10
#      11 # plotting the pie chart
# ---> 12 plt.pie(slices, labels = activities, colors=colors,
#      13         startangle=90, shadow = True, explode = (0, 0, 0.1),
#      14         radius = 1.2, autopct = '%1.1f%%')
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2772         wedgeprops=None, textprops=None, center=(0, 0), frame=False,
#    2773         rotatelabels=False, *, data=None):
# -> 2774     return gca().pie(
#    2775         x, explode=explode, labels=labels, colors=colors,
#    2776         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    3021             y += expl * math.sin(thetam)
#    3022
# -> 3023             w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3024                                360. * max(theta1, theta2),
#    3025                                facecolor=get_next_color(),
#
# /usr/lib/python3/dist-packages/matplotlib/patches.py in __init__(self, center, r, theta1, theta2, width, **kwargs)
#    1079         self.theta1, self.theta2 = theta1, theta2
#    1080         self._patch_transform = transforms.IdentityTransform()
# -> 1081         self._recompute_path()
#    1082
#    1083     def _recompute_path(self):
#
# /usr/lib/python3/dist-packages/matplotlib/patches.py in _recompute_path(self)
#    1091
#    1092         # Form the outer ring
# -> 1093         arc = Path.arc(theta1, theta2)
#    1094
#    1095         if self.width is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     836         # number of curve segments to make
#     837         if n is None:
# --> 838             n = int(2 ** np.ceil((eta2 - eta1) / halfpi))
#     839         if n < 1:
#     840             raise ValueError("n must be >= 1 or None")
#
# ValueError: cannot convert float NaN to integer
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
