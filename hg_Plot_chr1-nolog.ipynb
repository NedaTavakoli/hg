# %%
import numpy as np
import matplotlib.pyplot as plt
import fileinput
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from math import log
from matplotlib.dates import date2num
import datetime

# %%
# explicit function to normalize array
def normalize(arr, t_min, t_max):
    norm_arr = []
    diff = t_max - t_min
    diff_arr = max(arr) - min(arr)
    for i in arr:
        temp = (((i - min(arr))*diff)/diff_arr) + t_min
        norm_arr.append(temp)
    return norm_arr

# %% [markdown]
# # Chr 1

# %% [markdown]
# # 1- Variants retained while changing alpha (SNPs), delta = 10%

# %%
# Delta = 10% * alpha
import math

# %%
N_varinats_greedy = [13877,2188,679,531]
N_varinats_LP = [13650,2143,671,math.inf]
N_varinats_ILP_Hap = [3545,1503,244,164] # New
alpha = [150, 1000, 5000, 10000]

# %%
# # Normalize the arrays
# range_to_normalize = (0, 1)
# Normalized_N_varinats_greedy = normalize(N_varinats_greedy, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_LP = normalize(N_varinats_LP, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_ILP_Hap = normalize(N_varinats_ILP_Hap, range_to_normalize[0], range_to_normalize[1])
# print(Normalized_N_varinats_greedy)
# print(Normalized_N_varinats_LP)
# print(Normalized_N_varinats_ILP_Hap)

# %%
#data = [N_varinats_greedy,N_varinats_LP]
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]
# data = [Normalized_N_varinats_greedy,Normalized_N_varinats_LP,Normalized_N_varinats_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# plt.yscale("log")
# Get the y limits
ymin, ymax = 1,16000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
plt.ylim(ymin, ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
plt.legend(fontsize=17)

plt.savefig('[SNP]-nolog-1-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 2- Variants retained while changing delta for alpha = 150 (SNPs)

# %%
N_varinats_greedy = [6234046/400,3956014/400,346515/400,13877/400]
N_varinats_LP = [6234046/400,3946043/400,344842/400,13650/400]
N_varinats_ILP_Hap = [6234046/400,2355632/400,146312/600,3545/400] # New
delta = [0, 1, 5, 10]

# %%
# # Normalize the arrays
# range_to_normalize = (0, 1)
# Normalized_N_varinats_greedy = normalize(N_varinats_greedy, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_LP = normalize(N_varinats_LP, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_ILP_Hap = normalize(N_varinats_ILP_Hap, range_to_normalize[0], range_to_normalize[1])

# %%
# data = [N_varinats_greedy,N_varinats_LP]
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]
# data = [Normalized_N_varinats_greedy,Normalized_N_varinats_LP,Normalized_N_varinats_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-2-chr1.pdf', bbox_inches="tight")
plt.show()

# %%
N_varinats_greedy = [346515/400,13877/400]
N_varinats_LP = [344842/400,13650/400]
N_varinats_ILP_Hap = [146312/400,3545/400] # New
delta = [ 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]


X = np.arange(2)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,2), ['5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
# frame1 = plt.gca()
# frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,8000
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
# plt.ylim(ymin, ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-2-chr1_zoom.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 3- Variants retained while changing delta for alpha = 5000(SNPs)

# %%
N_varinats_greedy = [6234046/400,4037224/400,8808/400,679/400]
N_varinats_LP = [6234046/400,4024542/400,8808/400,671/400]
N_varinats_ILP_Hap = [ 6234046/400,1930345/400,5342/400,244/400] # New

delta = [0, 1, 5, 10]

# %%
# # Normalize the arrays
# range_to_normalize = (0, 1)
# Normalized_N_varinats_greedy = normalize(N_varinats_greedy, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_LP = normalize(N_varinats_LP, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_ILP_Hap = normalize(N_varinats_ILP_Hap, range_to_normalize[0], range_to_normalize[1])

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]
# data = [Normalized_N_varinats_greedy,Normalized_N_varinats_LP,Normalized_N_varinats_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
# plt.legend()
plt.savefig('[SNP]-nolog-3-chr1.pdf', bbox_inches="tight")
plt.show()

# %%
N_varinats_greedy = [8808/400,679/400]
N_varinats_LP = [8808/400,671/400]
N_varinats_ILP_Hap = [ 5342/400,244/400] # New

delta = [ 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]

X = np.arange(2)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,2), ['5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
# frame1 = plt.gca()
# frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,8000
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
# plt.ylim(ymin, ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-3-chr1_zoom.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 7- Time while changing alpha for delta = 10% (SNPs)

# %%
Time_greedy = [0.0659098, 0.085667,0.0853088, 0.0851969 ]
Time_LP = [30.0757, 72.5886, 264.976, math.inf]
Time_ILP_Hap = [20.0663,67.0651,125.0986,136.1091]

alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_LP,Time_ILP_Hap ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)


plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\delta =10\%$', fontsize=30)
#plt.legend()
plt.savefig('[SNP]-7-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 8- Time while changing delta for alpha = 150 (SNPs)

# %%
Time_greedy = [0.087552, 0.0982513, 0.067268,0.0659098]
Time_LP = [28.1266,167.196,38.8686,30.0757]
Time_ILP_Hap = [3.25452,12.0332,6.3456,3.8711]
delta = [0, 1, 5, 10]

# %%
data = [Time_greedy,Time_LP, Time_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New



plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =150$', fontsize=30)
#plt.legend()
plt.savefig('[SNP]-8-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 9- Time while changing delta for alpha = 5000 (SNPs)

# %%
Time_greedy = [0.0867964,0.100438, 0.085371,0.0853088]
Time_LP = [274.589,16534.2,272.774,272.774]
Time_ILP_Hap = [132.7601,145.0981,128.0176,125.0986]

delta = [0, 1, 5, 10]

# %%
data = [Time_greedy,Time_LP,Time_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =5000$', fontsize=30)
# plt.legend()
plt.savefig('[SNP]-9-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 10- Memory usage while changing alpha (SNPs), delta = 10%

# %%
Memory_usage_greedy = [118524/1000,122036/1000, 122028/1000,122036/1000]
Memory_usage_LP = [17437524/1000, 49635908/1000, 187701688/1000, math.inf]
Memory_usage_ILP_Hap = [13536524/1000,39335308/1000,112701678/1000,100701006/1000]

alpha = [150, 1000, 5000, 10000]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
# plt.legend()

plt.savefig('[SNP]-10-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 11- Memory usage while changing delta for alpha = 150 (SNPs)

# %%
Memory_usage_greedy = [183468/1000, 144652/1000, 118524/1000, 118524/1000]
Memory_usage_LP = [16431488/1000, 22580932/1000, 18901152/1000, 17437524/1000]
Memory_usage_ILP_Hap = [13421487/1000,13880811/1000,13801052/1000,13536524/1000]

delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]


X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)



plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
# plt.legend()
plt.savefig('[SNP]-11-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 12- Memory usage while changing delta for alpha = 5000 (SNPs)

# %%
Memory_usage_greedy = [183468/1000, 145292/1000, 122028/1000, 122028/1000]
Memory_usage_LP = [223957612/1000,283724184/1000,207778832/1000,187701688/1000]
Memory_usage_ILP_Hap = [118956612/1000,120624183/1000,114758832/1000,112701678/1000]

delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]


X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)


#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
# plt.legend()
plt.savefig('[SNP]-12-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Edit distance

# %% [markdown]
# # 1- Variants retained while changing alpha (INDEL), delta = 10%

# %%
N_varinats_greedy = [6512,5004,2641,2038]
N_varinats_Ilp = [6512,5005,2419,1748]
N_varinats_Ilp_pos = [6512,5005,2431,1758]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_varinats_greedy,N_varinats_Ilp,N_varinats_Ilp_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')



plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)


# Get the y limits
ymin, ymax = 0,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-1-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 2- Variants retained while changing delta(INDEL), alpha = 150

# %%
N_varinats_greedy = [6512,6512,6512,6512]
N_varinats_ILP = [6512,6512,6512,6512]
N_varinats_ILP_pos =[6512, 6512,6512, 6512]
delta = [0, 1, 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_ILP,N_varinats_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

#plt.yscale("log")
# Get the y limits
ymin, ymax = 0,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=20)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-2-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 3- Variants retained while changing delta(INDEL), alpha = 5000

# %%
N_varinats_greedy = [6512, 6399, 3827,2641]
N_varinats_ILP = [6512,6399, 3713,2419]
N_varinats_ILP_pos =[6512, 6399,3717,2431]
delta = [0, 1, 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_ILP,N_varinats_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')


plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

#plt.yscale("log")
# Get the y limits
ymin, ymax = 0,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-3-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 4- Positions retained while changing alpha (INDEL), delta = 10%

# %%
N_positions_greedy = [6356,4848,2541,1971]
N_positions_ILP = [6356,4849,2330,1687]
N_positions_ILP_pos = [6356,4849,2317,1680]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-4-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 5- Positions retained while changing delta for alpha = 150 (INDEL)

# %%
N_positions_greedy = [6356,6356,6356,6356]
N_positions_ILP = [6356,6356,6356,6356]
N_positions_ILP_pos = [6356,6356,6356,6356]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')
plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-5-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 6- Positions retained while changing delta for alpha = 5000 (INDEL)

# %%
N_positions_greedy = [6356,6243,3696,2541]
N_positions_ILP = [6356,6243,3583,2330]
N_positions_ILP_pos = [6356,6243,3578,2317]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')
plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,10000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-6-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 7- Time while changing alpha for delta = 10% (INDEL)

# %%
Time_greedy = [5.58523,26.4755,121.442,356.46]
Time_ILP = [5.55,26.7418,122.118,356.921]
Time_ILP_pos = [5.28695,26.5702,121.941,357.043]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# Get the y limits
ymin, ymax = 0.0001,400
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\delta =10\%$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-7-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 8- Time while changing delta for alpha = 150 (INDEL)

# %%
Time_greedy = [6.67852, 6.66402,5.48362,5.58523]
Time_ILP = [6.73822,6.73934, 5.24317,5.55]
Time_ILP_pos = [6.73971,6.7168,5.3279,5.28695]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 0.0001,400
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =150$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-8-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 9- Time while changing delta for alpha = 5000 (INDEL)

# %%
Time_greedy = [121.441,121.431,121.426,121.442]
Time_ILP = [121.542,121.571,124.708,122.118]
Time_ILP_pos = [121.545,121.537,121.804,121.941]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 0.0001,400
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =5000$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-9-chr1.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 10- Memory usage while changing alpha (INDEL), delta = 10%

# %%
Memory_usage_greedy = [2931444/1000, 2931244/1000, 2931352/1000,2931488/1000]
Memory_usage_ILP = [2931776/1000, 2931768/1000,2931876/1000,2932012/1000]
Memory_usage_ILP_pos = [2931772/1000,2931768/1000,2931840/1000,2932012/1000]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')
        
plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# Get the y limits
ymin, ymax = 0,5000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-10-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 11- Memory usage while changing delta for alpha = 150 (INDEL)

# %%
Memory_usage_greedy = [2931220/1000, 2931220/1000,2931444/1000,2931444/1000]
Memory_usage_ILP = [2931744/1000,2932380/1000,2931696/1000,2931776/1000]
Memory_usage_ILP_pos = [2931744/1000,2931744/1000,2931772/1000,2931772/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 0,5000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-11-chr1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 12- Memory usage while changing delta for alpha = 5000 (INDEL)

# %%
Memory_usage_greedy = [2931352/1000, 2931352/1000,2931352/1000,2931352/1000]
Memory_usage_ILP = [2931876/1000,2931840/1000,2931876/1000,2931876/1000]
Memory_usage_ILP_pos = [2931840/1000,2931876/1000,2931840/1000,2931840/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 0, 5000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-12-chr1.pdf', bbox_inches="tight")
plt.show()
